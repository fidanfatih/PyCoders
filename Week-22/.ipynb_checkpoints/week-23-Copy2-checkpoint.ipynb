# %% [markdown]
# # Week-23

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import re

# to avoid warnings
import warnings
warnings.filterwarnings('ignore')
warnings.warn("this will not show")

sns.set(style='darkgrid')
# %matplotlib inline

# %%
data = pd.read_csv('weatherAUS.csv').sample(10000)
df=data.copy()
df.head()
# Out:
#               Date       Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 35704   2015-03-24  SydneyAirport     20.4     26.5       0.0          6.8
# 116409  2014-02-22     PearceRAAF     24.7     35.5       0.0          NaN
# 75865   2011-07-05       Portland      7.3     12.2      15.0          2.0
# 51098   2014-11-05    Tuggeranong      8.9     26.1       0.0          NaN
# 35651   2015-01-30  SydneyAirport     14.3     25.2       0.0          8.8
#
#         Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  \
# 35704        2.2           S           39.0        SSE  ...        83.0
# 116409      10.8         ENE           44.0        ENE  ...        29.0
# 75865        4.1           W           93.0          W  ...        71.0
# 51098        NaN           S           44.0        WNW  ...        63.0
# 35651       11.2           S           43.0          W  ...        45.0
#
#         Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  \
# 35704          92.0       1011.9       1010.5       7.0       8.0     22.1
# 116409         18.0       1018.6       1014.1       NaN       1.0     27.9
# 75865          84.0       1005.3       1007.3       7.0       7.0     10.2
# 51098          27.0       1015.4       1010.1       NaN       NaN     14.3
# 35651          44.0       1009.6       1005.6       1.0       3.0     18.9
#
#         Temp3pm  RainToday  RainTomorrow
# 35704      21.6         No           Yes
# 116409     34.3         No            No
# 75865       9.6        Yes           Yes
# 51098      25.4         No            No
# 35651      23.3         No            No
#
# [5 rows x 23 columns]

# %%
df.shape
# Out:
# (10000, 23)

# %%
def null_values(df):
    """a function to show null values with percentage"""
    nv=pd.concat([df.isnull().sum(), 100 * df.isnull().sum()/df.shape[0]],axis=1).rename(columns={0:'Missing_Records', 1:'Percentage (%)'})
    return nv[nv.Missing_Records>0].sort_values('Missing_Records', ascending=False)
null_values(df)
# Out:
#                Missing_Records  Percentage (%)
# Sunshine                  4839           48.39
# Evaporation               4372           43.72
# Cloud3pm                  4090           40.90
# Cloud9am                  3913           39.13
# Pressure9am               1061           10.61
# Pressure3pm               1042           10.42
# WindGustDir                713            7.13
# WindGustSpeed              711            7.11
# WindDir9am                 684            6.84
# Humidity3pm                327            3.27
# WindDir3pm                 291            2.91
# Rainfall                   260            2.60
# RainToday                  260            2.60
# Temp3pm                    256            2.56
# RainTomorrow               235            2.35
# WindSpeed3pm               231            2.31
# Humidity9am                202            2.02
# WindSpeed9am               142            1.42
# Temp9am                    140            1.40
# MinTemp                    114            1.14
# MaxTemp                    101            1.01

# %%
df.dropna(subset=['RainToday', 'RainTomorrow'], inplace=True)
df[['RainToday', 'RainTomorrow']].isnull().sum()
# Out:
# RainToday       0
# RainTomorrow    0
# dtype: int64

# %%
def summary(df, pred=None):
    obs = df.shape[0]
    Types = df.dtypes
    Counts = df.apply(lambda x: x.count())
    Min = df.min()
    Max = df.max()
    Uniques = df.apply(lambda x: x.unique().shape[0])
    Nulls = df.apply(lambda x: x.isnull().sum())
    print('Data shape:', df.shape)

    if pred is None:
        cols = ['Types', 'Counts', 'Uniques', 'Nulls', 'Min', 'Max']
        str = pd.concat([Types, Counts, Uniques, Nulls, Min, Max], axis = 1, sort=True)

    str.columns = cols
    print('___________________________\nData Types:')
    print(str.Types.value_counts())
    print('___________________________')
    display(str.sort_values(by='Nulls', ascending=False))

summary(df)
# Out:
# Data shape: (9654, 23)
# ___________________________
# Data Types:
# float64    16
# object      7
# Name: Types, dtype: int64
# ___________________________
#                  Types  Counts  Uniques  Nulls         Min         Max
# Sunshine       float64    5035      142   4619           0        14.3
# Evaporation    float64    5517      178   4137           0        60.2
# Cloud3pm       float64    5798       10   3856           0           8
# Cloud9am       float64    5980       10   3674           0           8
# Pressure9am    float64    8708      426    946       984.6      1038.9
# Pressure3pm    float64    8715      421    939       982.2      1036.6
# WindGustDir     object    9024       17    630         NaN         NaN
# WindGustSpeed  float64    9025       57    629           9         124
# WindDir9am      object    9048       17    606         NaN         NaN
# Humidity3pm    float64    9410      101    244           1         100
# WindDir3pm      object    9414       17    240         NaN         NaN
# WindSpeed3pm   float64    9473       37    181           0          83
# Temp3pm        float64    9481      403    173        -3.9        44.8
# Humidity9am    float64    9544       98    110           4         100
# WindSpeed9am   float64    9571       35     83           0          67
# Temp9am        float64    9606      363     48        -4.3        37.3
# MinTemp        float64    9627      346     27        -6.7        33.9
# MaxTemp        float64    9633      402     21        -3.1          47
# Rainfall       float64    9654      258      0           0         371
# RainTomorrow    object    9654        2      0          No         Yes
# Location        object    9654       49      0    Adelaide     Woomera
# Date            object    9654     3017      0  2007-11-12  2017-06-25
# RainToday       object    9654        2      0          No         Yes

# %%
df[['RainToday','RainTomorrow']] = df[['RainToday','RainTomorrow']].replace({'Yes':1, 'No':0})

# %% [markdown]
# ### Multivariate Imputation

# %%
# Iterative Imputer default=BayesianRidge()

from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

df_multi_imputation = df.copy()
idf = df_multi_imputation.drop(['Date','Location'], axis=1)
idf = pd.get_dummies(idf, drop_first=True, columns = ['WindDir9am','WindDir3pm','WindGustDir'])

imp_mean = IterativeImputer(missing_values=np.nan, initial_strategy='mean', random_state=42)
df_imputed_bayesian = pd.DataFrame(imp_mean.fit_transform(idf), index=idf.index, columns=idf.columns)
null_values(df_imputed_bayesian)
# Out:
# Empty DataFrame
# Columns: [Missing_Records, Percentage (%)]
# Index: []

# %%
summary(df_imputed_bayesian.iloc[:,:50])
# Out:
# Data shape: (9654, 50)
# ___________________________
# Data Types:
# float64    50
# Name: Types, dtype: int64
# ___________________________
#                    Types  Counts  Uniques  Nulls         Min          Max
# Cloud3pm         float64    9654     3864      0    0.000000    11.959650
# WindDir9am_S     float64    9654        2      0    0.000000     1.000000
# WindDir3pm_W     float64    9654        2      0    0.000000     1.000000
# WindDir3pm_WNW   float64    9654        2      0    0.000000     1.000000
# WindDir3pm_WSW   float64    9654        2      0    0.000000     1.000000
# WindDir9am_ENE   float64    9654        2      0    0.000000     1.000000
# WindDir9am_ESE   float64    9654        2      0    0.000000     1.000000
# WindDir9am_N     float64    9654        2      0    0.000000     1.000000
# WindDir9am_NE    float64    9654        2      0    0.000000     1.000000
# WindDir9am_NNE   float64    9654        2      0    0.000000     1.000000
# WindDir9am_NNW   float64    9654        2      0    0.000000     1.000000
# WindDir9am_NW    float64    9654        2      0    0.000000     1.000000
# WindDir9am_SE    float64    9654        2      0    0.000000     1.000000
# Cloud9am         float64    9654     3683      0   -2.015131    10.668932
# WindDir9am_SSE   float64    9654        2      0    0.000000     1.000000
# WindDir9am_SSW   float64    9654        2      0    0.000000     1.000000
# WindDir9am_SW    float64    9654        2      0    0.000000     1.000000
# WindDir9am_W     float64    9654        2      0    0.000000     1.000000
# WindDir9am_WNW   float64    9654        2      0    0.000000     1.000000
# WindDir9am_WSW   float64    9654        2      0    0.000000     1.000000
# WindGustDir_ENE  float64    9654        2      0    0.000000     1.000000
# WindGustDir_ESE  float64    9654        2      0    0.000000     1.000000
# WindGustSpeed    float64    9654      685      0    9.000000   124.000000
# WindSpeed3pm     float64    9654      217      0    0.000000    83.000000
# WindDir3pm_SW    float64    9654        2      0    0.000000     1.000000
# WindDir3pm_SSW   float64    9654        2      0    0.000000     1.000000
# WindDir3pm_SSE   float64    9654        2      0    0.000000     1.000000
# WindDir3pm_SE    float64    9654        2      0    0.000000     1.000000
# Evaporation      float64    9654     4314      0   -3.272836    60.200000
# Humidity3pm      float64    9654      344      0   -3.140525   100.000000
# Humidity9am      float64    9654      207      0    4.000000   101.103288
# MaxTemp          float64    9654      422      0   -3.100000    47.000000
# MinTemp          float64    9654      372      0   -6.700000    33.900000
# Pressure3pm      float64    9654     1358      0  982.200000  1036.600000
# Pressure9am      float64    9654     1370      0  984.600000  1038.900000
# RainToday        float64    9654        2      0    0.000000     1.000000
# RainTomorrow     float64    9654        2      0    0.000000     1.000000
# Rainfall         float64    9654      258      0    0.000000   371.000000
# Sunshine         float64    9654     4760      0   -0.860864    14.865303
# Temp3pm          float64    9654      575      0   -3.900000    44.800000
# Temp9am          float64    9654      410      0   -4.300000    37.300000
# WindDir3pm_ENE   float64    9654        2      0    0.000000     1.000000
# WindDir3pm_ESE   float64    9654        2      0    0.000000     1.000000
# WindDir3pm_N     float64    9654        2      0    0.000000     1.000000
# WindDir3pm_NE    float64    9654        2      0    0.000000     1.000000
# WindDir3pm_NNE   float64    9654        2      0    0.000000     1.000000
# WindDir3pm_NNW   float64    9654        2      0    0.000000     1.000000
# WindDir3pm_NW    float64    9654        2      0    0.000000     1.000000
# WindDir3pm_S     float64    9654        2      0    0.000000     1.000000
# WindSpeed9am     float64    9654      116      0    0.000000    67.000000

# %%
# with decision tree
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.tree import DecisionTreeRegressor

df_multi_imputation = df.copy()
idf = df_multi_imputation.drop(['Date','Location'], axis=1)
idf = pd.get_dummies(idf, drop_first=True, columns = ['WindDir9am','WindDir3pm','WindGustDir'])

imp_mean = IterativeImputer(missing_values=np.nan, initial_strategy='mean', random_state=42, estimator=DecisionTreeRegressor())
df_imputed_dt = pd.DataFrame(imp_mean.fit_transform(idf), index=idf.index, columns=idf.columns)
null_values(df_imputed_dt)
# Out:
# Empty DataFrame
# Columns: [Missing_Records, Percentage (%)]
# Index: []

# %%
summary(df_imputed_dt.iloc[:,:50])
# Out:
# Data shape: (9654, 50)
# ___________________________
# Data Types:
# float64    50
# Name: Types, dtype: int64
# ___________________________
#                    Types  Counts  Uniques  Nulls    Min     Max
# Cloud3pm         float64    9654        9      0    0.0     8.0
# WindDir9am_S     float64    9654        2      0    0.0     1.0
# WindDir3pm_W     float64    9654        2      0    0.0     1.0
# WindDir3pm_WNW   float64    9654        2      0    0.0     1.0
# WindDir3pm_WSW   float64    9654        2      0    0.0     1.0
# WindDir9am_ENE   float64    9654        2      0    0.0     1.0
# WindDir9am_ESE   float64    9654        2      0    0.0     1.0
# WindDir9am_N     float64    9654        2      0    0.0     1.0
# WindDir9am_NE    float64    9654        2      0    0.0     1.0
# WindDir9am_NNE   float64    9654        2      0    0.0     1.0
# WindDir9am_NNW   float64    9654        2      0    0.0     1.0
# WindDir9am_NW    float64    9654        2      0    0.0     1.0
# WindDir9am_SE    float64    9654        2      0    0.0     1.0
# Cloud9am         float64    9654        9      0    0.0     8.0
# WindDir9am_SSE   float64    9654        2      0    0.0     1.0
# WindDir9am_SSW   float64    9654        2      0    0.0     1.0
# WindDir9am_SW    float64    9654        2      0    0.0     1.0
# WindDir9am_W     float64    9654        2      0    0.0     1.0
# WindDir9am_WNW   float64    9654        2      0    0.0     1.0
# WindDir9am_WSW   float64    9654        2      0    0.0     1.0
# WindGustDir_ENE  float64    9654        2      0    0.0     1.0
# WindGustDir_ESE  float64    9654        2      0    0.0     1.0
# WindGustSpeed    float64    9654       56      0    9.0   124.0
# WindSpeed3pm     float64    9654       36      0    0.0    83.0
# WindDir3pm_SW    float64    9654        2      0    0.0     1.0
# WindDir3pm_SSW   float64    9654        2      0    0.0     1.0
# WindDir3pm_SSE   float64    9654        2      0    0.0     1.0
# WindDir3pm_SE    float64    9654        2      0    0.0     1.0
# Evaporation      float64    9654      185      0    0.0    60.2
# Humidity3pm      float64    9654      100      0    1.0   100.0
# Humidity9am      float64    9654       97      0    4.0   100.0
# MaxTemp          float64    9654      401      0   -3.1    47.0
# MinTemp          float64    9654      345      0   -6.7    33.9
# Pressure3pm      float64    9654      421      0  982.2  1036.6
# Pressure9am      float64    9654      426      0  984.6  1038.9
# RainToday        float64    9654        2      0    0.0     1.0
# RainTomorrow     float64    9654        2      0    0.0     1.0
# Rainfall         float64    9654      258      0    0.0   371.0
# Sunshine         float64    9654      145      0    0.0    14.3
# Temp3pm          float64    9654      402      0   -3.9    44.8
# Temp9am          float64    9654      363      0   -4.3    37.3
# WindDir3pm_ENE   float64    9654        2      0    0.0     1.0
# WindDir3pm_ESE   float64    9654        2      0    0.0     1.0
# WindDir3pm_N     float64    9654        2      0    0.0     1.0
# WindDir3pm_NE    float64    9654        2      0    0.0     1.0
# WindDir3pm_NNE   float64    9654        2      0    0.0     1.0
# WindDir3pm_NNW   float64    9654        2      0    0.0     1.0
# WindDir3pm_NW    float64    9654        2      0    0.0     1.0
# WindDir3pm_S     float64    9654        2      0    0.0     1.0
# WindSpeed9am     float64    9654       34      0    0.0    67.0

# %%
# with knn
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.neighbors import KNeighborsRegressor

df_multi_imputation = df.copy()
idf = df_multi_imputation.drop(['Date','Location'], axis=1)
idf = pd.get_dummies(idf, drop_first=True, columns = ['WindDir9am','WindDir3pm','WindGustDir'])

imp_mean = IterativeImputer(missing_values=np.nan, initial_strategy='mean', random_state=42, estimator=KNeighborsRegressor())
df_imputed_knn = pd.DataFrame(imp_mean.fit_transform(idf), index=idf.index, columns=idf.columns)
null_values(df_imputed_knn)
# Out:
# Empty DataFrame
# Columns: [Missing_Records, Percentage (%)]
# Index: []

# %%
summary(df_imputed_knn.iloc[:,:60])
# Out:
# Data shape: (9654, 60)
# ___________________________
# Data Types:
# float64    60
# Name: Types, dtype: int64
# ___________________________
#                    Types  Counts  Uniques  Nulls    Min     Max
# Cloud3pm         float64    9654       41      0    0.0     8.0
# Cloud9am         float64    9654       41      0    0.0     8.0
# WindDir9am_N     float64    9654        2      0    0.0     1.0
# WindDir9am_NE    float64    9654        2      0    0.0     1.0
# WindDir9am_NNE   float64    9654        2      0    0.0     1.0
# WindDir9am_NNW   float64    9654        2      0    0.0     1.0
# WindDir9am_NW    float64    9654        2      0    0.0     1.0
# WindDir9am_S     float64    9654        2      0    0.0     1.0
# WindDir9am_SE    float64    9654        2      0    0.0     1.0
# WindDir9am_SSE   float64    9654        2      0    0.0     1.0
# WindDir9am_SSW   float64    9654        2      0    0.0     1.0
# WindDir9am_SW    float64    9654        2      0    0.0     1.0
# WindDir9am_W     float64    9654        2      0    0.0     1.0
# WindDir9am_WNW   float64    9654        2      0    0.0     1.0
# WindDir9am_WSW   float64    9654        2      0    0.0     1.0
# WindGustDir_ENE  float64    9654        2      0    0.0     1.0
# WindGustDir_ESE  float64    9654        2      0    0.0     1.0
# WindGustDir_N    float64    9654        2      0    0.0     1.0
# WindGustDir_NE   float64    9654        2      0    0.0     1.0
# WindGustDir_NNE  float64    9654        2      0    0.0     1.0
# WindGustDir_NNW  float64    9654        2      0    0.0     1.0
# WindGustDir_NW   float64    9654        2      0    0.0     1.0
# WindGustDir_S    float64    9654        2      0    0.0     1.0
# WindGustDir_SE   float64    9654        2      0    0.0     1.0
# WindGustDir_SSE  float64    9654        2      0    0.0     1.0
# WindGustDir_SSW  float64    9654        2      0    0.0     1.0
# WindGustDir_SW   float64    9654        2      0    0.0     1.0
# WindGustSpeed    float64    9654      241      0    9.0   124.0
# WindSpeed3pm     float64    9654      114      0    0.0    83.0
# WindDir9am_ESE   float64    9654        2      0    0.0     1.0
# WindDir9am_ENE   float64    9654        2      0    0.0     1.0
# WindDir3pm_WSW   float64    9654        2      0    0.0     1.0
# Temp9am          float64    9654      403      0   -4.3    37.3
# Evaporation      float64    9654      900      0    0.0    60.2
# Humidity3pm      float64    9654      236      0    1.0   100.0
# Humidity9am      float64    9654      163      0    4.0   100.0
# MaxTemp          float64    9654      418      0   -3.1    47.0
# MinTemp          float64    9654      362      0   -6.7    33.9
# Pressure3pm      float64    9654      970      0  982.2  1036.6
# Pressure9am      float64    9654      997      0  984.6  1038.9
# RainToday        float64    9654        2      0    0.0     1.0
# RainTomorrow     float64    9654        2      0    0.0     1.0
# Rainfall         float64    9654      258      0    0.0   371.0
# Sunshine         float64    9654     1178      0    0.0    14.3
# Temp3pm          float64    9654      536      0   -3.9    44.8
# WindDir3pm_ENE   float64    9654        2      0    0.0     1.0
# WindDir3pm_WNW   float64    9654        2      0    0.0     1.0
# WindDir3pm_ESE   float64    9654        2      0    0.0     1.0
# WindDir3pm_N     float64    9654        2      0    0.0     1.0
# WindDir3pm_NE    float64    9654        2      0    0.0     1.0
# WindDir3pm_NNE   float64    9654        2      0    0.0     1.0
# WindDir3pm_NNW   float64    9654        2      0    0.0     1.0
# WindDir3pm_NW    float64    9654        2      0    0.0     1.0
# WindDir3pm_S     float64    9654        2      0    0.0     1.0
# WindDir3pm_SE    float64    9654        2      0    0.0     1.0
# WindDir3pm_SSE   float64    9654        2      0    0.0     1.0
# WindDir3pm_SSW   float64    9654        2      0    0.0     1.0
# WindDir3pm_SW    float64    9654        2      0    0.0     1.0
# WindDir3pm_W     float64    9654        2      0    0.0     1.0
# WindSpeed9am     float64    9654       86      0    0.0    67.0

# %%
summary(df_imputed_knn.iloc[:,60:])
# Out:
# Data shape: (9654, 3)
# ___________________________
# Data Types:
# float64    3
# Name: Types, dtype: int64
# ___________________________
#                    Types  Counts  Uniques  Nulls  Min  Max
# WindGustDir_W    float64    9654        2      0  0.0  1.0
# WindGustDir_WNW  float64    9654        2      0  0.0  1.0
# WindGustDir_WSW  float64    9654        2      0  0.0  1.0

# %% [markdown]
# with bayesian and decisian tree models, There are some anomaies in numeric values. Except that temperature features, Any features shouldnt have negative values. So We have to prefer knn for `Multivariate Imputation`

# %% [markdown]
# ## Outliers

# %% [markdown]
# #### Functions

# %%
from numpy import percentile
from scipy.stats import zscore
from scipy import stats

def outlier_zscore(df, col, min_z=1, max_z = 5, step = 0.1, print_list = False):
    z_scores = zscore(df[col].dropna())
    threshold_list = []
    for threshold in np.arange(min_z, max_z, step):
        threshold_list.append((threshold, len(np.where(z_scores > threshold)[0])))
        df_outlier = pd.DataFrame(threshold_list, columns = ['threshold', 'outlier_count'])
        df_outlier['pct'] = (df_outlier.outlier_count - df_outlier.outlier_count.shift(-1))/df_outlier.outlier_count*100
    plt.plot(df_outlier.threshold, df_outlier.outlier_count)
    best_treshold = round(df_outlier.iloc[df_outlier.pct.argmax(), 0],2)
    outlier_limit = int(df[col].dropna().mean() + (df[col].dropna().std()) * df_outlier.iloc[df_outlier.pct.argmax(), 0])
    percentile_threshold = stats.percentileofscore(df[col].dropna(), outlier_limit)
    plt.vlines(best_treshold, 0, df_outlier.outlier_count.max(), 
               colors="r", ls = ":"
              )
    plt.annotate("Zscore : {}\nValue : {}\nPercentile : {}".format(best_treshold, outlier_limit, 
                                                                   (np.round(percentile_threshold, 3), 
                                                                    np.round(100-percentile_threshold, 3))), 
                 (best_treshold, df_outlier.outlier_count.max()/2))
    #plt.show()
    if print_list:
        print(df_outlier)
    return (plt, df_outlier, best_treshold, outlier_limit, percentile)

# %%
from scipy.stats import zscore
from scipy import stats

def outlier_inspect(df, col, min_z=1, max_z = 5, step = 0.5, max_hist = None, bins = 50):
    fig = plt.figure(figsize=(20, 6))
    fig.suptitle(col, fontsize=16)
    plt.subplot(1,3,1)
    if max_hist == None:
        sns.distplot(df[col], kde=False, bins = 50)
    else :
        sns.distplot(df[df[col]<=max_hist][col], kde=False, bins = 50)
   
    plt.subplot(1,3,2)
    sns.boxplot(df[col])
    plt.subplot(1,3,3)
    z_score_inspect = outlier_zscore(df, col, min_z=min_z, max_z = max_z, step = step)
    
    plt.subplot(1,3,1)
    plt.axvline(x=df[col].mean() + z_score_inspect[2]*df[col].std(),color='red',linewidth=1,linestyle ="--")
    plt.axvline(x=df[col].mean() - z_score_inspect[2]*df[col].std(),color='red',linewidth=1,linestyle ="--")
    plt.show()
    
    return z_score_inspect

# %%
def detect_outliers(df:pd.DataFrame, col_name:str, p=1.5) ->int:
    ''' 
    this function detects outliers based on 3 time IQR and
    returns the number of lower and uper limit and number of outliers respectively
    '''
    first_quartile = np.percentile(np.array(df[col_name].tolist()), 25)
    third_quartile = np.percentile(np.array(df[col_name].tolist()), 75)
    IQR = third_quartile - first_quartile
                      
    upper_limit = third_quartile+(p*IQR)
    lower_limit = first_quartile-(p*IQR)
    outlier_count = 0
                      
    for value in df[col_name].tolist():
        if (value < lower_limit) | (value > upper_limit):
            outlier_count +=1
    return lower_limit, upper_limit, outlier_count

# %% [markdown]
# ### Outliers according to Z-score

# %%
from scipy import stats

numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
df_numeric = df_imputed_knn.iloc[:,:16].select_dtypes(include=numerics)

z = np.abs(stats.zscore(df_numeric))
threshold = 3
print('list of outliers:', '\n', np.where(z > 3)[0], '\n', np.where(z > 3)[1])
print('number of outliers:', np.where(z > 3)[0].shape)
# Out:
# list of outliers:
#  [   2    2   49   54   61   74  111  120  129  140  142  145  156  159
#   223  236  242  262  277  291  295  306  306  319  319  319  319  335
#   335  383  402  424  446  448  448  470  475  501  549  590  591  592
#   599  639  649  651  677  736  751  754  790  828  875  875  875  878
#   883  883  883  886  893  901  910  942  956  956  956  956  958  965
#   968  971  986  986 1015 1053 1056 1068 1077 1217 1219 1219 1240 1261
#  1298 1308 1315 1382 1418 1454 1458 1460 1462 1463 1464 1464 1464 1500
#  1510 1581 1604 1615 1625 1633 1638 1644 1644 1644 1644 1648 1652 1673
#  1698 1731 1745 1796 1829 1831 1837 1852 1868 1883 1886 1977 2059 2066
#  2081 2084 2111 2112 2150 2169 2178 2182 2191 2212 2214 2222 2222 2222
#  2225 2252 2252 2255 2255 2260 2290 2349 2363 2394 2401 2428 2428 2428
#  2441 2472 2482 2495 2546 2547 2594 2608 2696 2728 2728 2728 2760 2784
#  2790 2812 2821 2821 2847 2847 2877 2877 2888 2888 2903 2955 2955 2955
#  2971 2995 2995 3008 3014 3023 3023 3038 3049 3064 3077 3108 3123 3125
#  3125 3134 3138 3170 3170 3176 3193 3207 3215 3215 3216 3257 3279 3285
#  3289 3304 3307 3340 3350 3350 3354 3358 3431 3480 3495 3528 3554 3556
#  3580 3633 3656 3668 3670 3681 3697 3720 3735 3741 3779 3786 3829 3856
#  3868 3876 3876 3876 3906 3913 3916 3948 3970 3970 3984 4002 4034 4117
#  4118 4160 4169 4193 4200 4200 4231 4245 4245 4245 4251 4293 4293 4293
#  4303 4322 4322 4335 4357 4377 4390 4432 4488 4542 4546 4551 4554 4571
#  4577 4586 4636 4636 4636 4647 4647 4647 4652 4678 4691 4699 4700 4716
#  4727 4763 4785 4825 4847 4899 4940 4949 4951 4957 4957 4961 4996 5001
#  5001 5010 5021 5021 5031 5031 5031 5032 5034 5043 5045 5045 5045 5045
#  5045 5047 5047 5056 5056 5056 5083 5085 5085 5085 5121 5131 5139 5139
#  5139 5143 5174 5181 5209 5222 5256 5256 5281 5281 5290 5290 5333 5374
#  5378 5382 5406 5433 5460 5473 5484 5492 5552 5552 5570 5575 5581 5597
#  5597 5612 5634 5650 5677 5684 5694 5720 5720 5744 5744 5744 5747 5747
#  5760 5765 5777 5785 5849 5852 5857 5864 5864 5864 5883 5895 5907 5908
#  5913 5914 5931 5954 6010 6013 6013 6053 6102 6119 6124 6129 6135 6135
#  6137 6137 6173 6178 6181 6190 6202 6202 6203 6210 6210 6247 6247 6247
#  6267 6268 6271 6272 6300 6300 6300 6300 6359 6359 6434 6485 6485 6508
#  6555 6563 6590 6615 6615 6640 6649 6652 6663 6669 6679 6719 6721 6746
#  6758 6765 6781 6783 6792 6829 6836 6836 6836 6836 6854 6863 6896 6922
#  6925 6934 6966 6966 6972 7009 7072 7077 7083 7097 7097 7097 7100 7101
#  7101 7105 7107 7115 7115 7121 7123 7161 7162 7170 7193 7195 7201 7201
#  7208 7215 7232 7253 7318 7332 7332 7337 7337 7337 7337 7337 7356 7364
#  7364 7375 7420 7436 7453 7467 7467 7467 7467 7475 7475 7477 7526 7526
#  7531 7537 7569 7642 7656 7709 7752 7752 7752 7763 7767 7820 7842 7870
#  7880 7914 7925 7931 7931 7952 7964 7977 7979 7979 7979 7979 8023 8035
#  8050 8062 8062 8064 8064 8067 8070 8094 8098 8117 8130 8181 8184 8225
#  8243 8243 8267 8359 8359 8385 8389 8389 8414 8419 8449 8468 8481 8481
#  8497 8516 8598 8598 8598 8605 8609 8609 8619 8629 8629 8629 8673 8693
#  8694 8748 8756 8769 8826 8879 8879 8879 8909 8910 8914 8921 8924 8924
#  8924 8941 8947 8947 8947 8953 8963 8978 8998 9027 9039 9059 9068 9073
#  9073 9080 9094 9130 9227 9227 9237 9241 9272 9299 9304 9304 9305 9337
#  9343 9343 9358 9384 9392 9392 9413 9440 9456 9460 9460 9460 9498 9518
#  9523 9554 9555 9564 9566 9587 9587 9593 9599 9601 9606 9626 9634 9638
#  9643]
#  [ 5  6  6  2  6 15  2  5  2  2  8  8  3  2  3  7  2  2  2  6  2  5  7  5
#   6  7 10  1 15  3  2  2  8 10 11 11  8  3  6  2  7  3  2  8  6  5  7  2
#   5  3  3  2  5  7 10  2  1 14 15  3  2  3  7  2  3  5  6  7  3  6  2  6
#   3  8  2  2  8  6  2  2 10 11  3  2  2  7  5  5  5  2  2  8  3  2  5 10
#  11  7  3 10  2  3  5 10  8  5  7 10 11  5  3  2  3  3  6  2  2  3  6  2
#   7  6  3  3 10  3  2  3  5  8  6  5  2  2  6  8  3  5  6  7  7  6  7  5
#   7  2  5  2  6 11  3  5  6  7  2  5  8  2  2  2  3  2  2  2  5  6  6  7
#   2  6  5  6  5  7  2  3  7 11  5  1  3 15  2 10 11  5  7  5  7  3  3  3
#   5  5  3 10 11  5  2  2  5  6  2  8 10 11  2  2  2  8 14  7  2  2  1  5
#   6  5  6  2  2  2  3  5  3  6  2  6  3  2  2  2  6  5  8  8  3  3  7  1
#   5 15  3  2  3  5  5  7  2 10  6  2  3  3  7  3  1 15  3  1 14 15  7  5
#  10 11  5  2  6  3  7  3  8 11  5  3  3  7  2  2  5  2  5  6  7  5  6  7
#   2  6  2  3  3  2  2  2  8  2  2  6  3 10  2 10 11  7  8  5  7  7  2  6
#   5  6  7  2  5  3  5  6  7 10 11  5 11  1 14 15  2  5  6  7  2 15  5 10
#  11  6  5  6 11  2  5 11 10 11  5  6  2  2  6  2  3  3  2  3  3  8  5  6
#   6  5  2  8 14  2  2  3  6  2  6  6  7  1 14 15  5 10  6  2  6  3  2  5
#   2  1 14 15  3  8  2  2  2  6  2  6  2  1 15  3  3  7  6  5 10 11  5  7
#   2  2  5  3 10 11  3  5  7  5  6  7  2  3 11  2  5  7 10 11  5 15  2  5
#  10  5  6  3  8  3  8  2  8 15  3 10  3  5  1  3  7  2  2  3  3  2  5  7
#  10 11  3  5  6  2  5  2 10 11  3  2  3  7  2  5 10 11 10  1 15  7  6 10
#  11  5 15  2  8  7  2  2  2  5  3  2  3  2  6 10 11  5  6  7 10 11  2  1
#  15  2  5  6  3  1  5 14 15  3 15  6  5  6  2  2  5 11  2  2  5  6  7  6
#   6  6  2  5  3  2  2  0 14  7  2  7  2  7 10 11  2  7  3 10 11 10 11  3
#   5  3  3  2  5  3  3  3  6  7  2  5  7  2  5  7  2  7 10  2  3  5  2  2
#   5  6  7 11  5  7  8  5  7 11  2  6  6  7  6  3  3  2  6  7  3  5  2  8
#   1 14 15  6  2 10 11  3  2  5  8  3  2  2  6  5  7  6  2  6  2  6  3 11
#  11  5  5  7  2  2  3  6  2  6  5  7  2  3  3  2  5  6  2  3  3  3  6  3
#   2  1 15  2  2  6  5  7  3 10  3]
# number of outliers: (659,)

# %% [markdown]
# ### Outliers according to 1.5 * IQR

# %%
# Example: maxTemp
Q1_maxTemp = df_imputed_knn.MaxTemp.quantile(0.25)
Q3_maxTemp = df_imputed_knn.MaxTemp.quantile(0.75)
IQR_maxTemp = Q3_maxTemp - Q1_maxTemp
upper_maxTemp = Q3_maxTemp + 1.5 * IQR_maxTemp
lower_maxTemp = Q1_maxTemp - 1.5 * IQR_maxTemp
print(f"""
Q1_maxTemp = {Q1_maxTemp}
Q3_maxTemp = {Q3_maxTemp}
IQR_maxTemp = {IQR_maxTemp}
upper_maxTemp = {upper_maxTemp}
lower_maxTemp = {lower_maxTemp}
""")
# Out:
# Q1_maxTemp = 18.0
# Q3_maxTemp = 28.3
# IQR_maxTemp = 10.3
# upper_maxTemp = 43.75
# lower_maxTemp = 2.549999999999999

# %%
# Q1, Q3 and IQR values for each variable
Q1 = df_numeric.quantile(0.25)
Q3 = df_numeric.quantile(0.75)
IQR = Q3 - Q1
pd.concat([Q1, Q3, IQR], axis=1, keys= ['Q1', 'Q3', 'IQR'])
# Out:
#                     Q1        Q3     IQR
# MinTemp           7.60    17.000   9.400
# MaxTemp          18.00    28.300  10.300
# Rainfall          0.00     0.600   0.600
# Evaporation       2.60     6.800   4.200
# Sunshine          4.96    10.400   5.440
# WindGustSpeed    31.00    47.000  16.000
# WindSpeed9am      7.00    19.000  12.000
# WindSpeed3pm     13.00    24.000  11.000
# Humidity9am      57.00    83.000  26.000
# Humidity3pm      36.00    66.000  30.000
# Pressure9am    1013.20  1022.495   9.295
# Pressure3pm    1010.68  1020.000   9.320
# Cloud9am          2.00     7.000   5.000
# Cloud3pm          2.20     7.000   4.800
# Temp9am          12.40    21.800   9.400
# Temp3pm          16.70    26.600   9.900

# %%
features=df_imputed_knn.columns[:16]

# %%
# Number of outliers in each column ignoring zero values by 1.5*IQR
k=1.5
print(f"Number of Outliers for {k}*IQR\n")

total=0
for col in features:
    outliers=detect_outliers(df_imputed_knn[df_imputed_knn[col] != 0], col, k)[2]
    total+=outliers
    if outliers > 0:
        print("{} outliers in '{}'".format(outliers,col))
# print("\n{} OUTLIERS TOTALLY".format(total))
# Out:
# Number of Outliers for 1.5*IQR
#
# 5 outliers in 'MinTemp'
# 23 outliers in 'MaxTemp'
# 323 outliers in 'Rainfall'
# 290 outliers in 'Evaporation'
# 265 outliers in 'WindGustSpeed'
# 153 outliers in 'WindSpeed9am'
# 157 outliers in 'WindSpeed3pm'
# 90 outliers in 'Humidity9am'
# 84 outliers in 'Pressure9am'
# 93 outliers in 'Pressure3pm'
# 11 outliers in 'Temp9am'
# 29 outliers in 'Temp3pm'

# %% [markdown]
# ### Plotting outliers

# %%
def col_plot(df,col_name):
    plt.figure(figsize=(15,6))
    
    plt.subplot(141) # 1 satir x 4 sutun dan olusan ax in 1. sutununda calis
    plt.hist(df[col_name], bins = 20)
    f=lambda x:(np.sqrt(x) if x>=0 else -np.sqrt(-x))
    
    # üç sigma aralikta(verinin %99.7 sini icine almasi beklenen bolum) iki kirmizi cizgi arasinda
    plt.axvline(x=df[col_name].mean() + 3*df[col_name].std(),color='red')
    plt.axvline(x=df[col_name].mean() - 3*df[col_name].std(),color='red')
    plt.xlabel(col_name)
    plt.tight_layout
    plt.xlabel("Histogram ±3z")
    plt.ylabel(col_name)

    plt.subplot(142)
    plt.boxplot(df[col_name]) # IQR katsayisi, defaultu 1.5
    plt.xlabel("IQR=1.5")

    plt.subplot(143)
    plt.boxplot(df[col_name].apply(f), whis = 1.5)
    plt.xlabel("ROOT SQUARE - IQR=1.5")

    plt.subplot(144)
    plt.boxplot(np.log(df[col_name]+0.1), whis = 1.5)
    plt.xlabel("LOGARITMIC - IQR=1.5")
    plt.show()

# %%
for i in df_imputed_knn.columns[:16]:
    col_plot(df_imputed_knn,i)

# %%
z_scores=[]
for i in df_imputed_knn.columns[:16]:
    z_scores.append(outlier_inspect(df_imputed_knn,i)[2])

# %%
# verinin 99% confidence interval daki z score lari.
print(z_scores)
# Out:
# [3.0, 3.0, 1.0, 1.0, 1.5, 4.0, 1.5, 1.0, 1.5, 2.0, 3.0, 3.0, 1.0, 1.0, 3.0, 3.0]

# %% [markdown]
# ### Dropping outliers

# %%
# create columns for 3z scores, new column with z score
df_3z=df_imputed_knn.copy()

for x in df_imputed_knn.columns[:16]:
    df_3z[x + '_z'] = stats.zscore(df_3z[x])

for x in df_3z.columns[-len(df_imputed_knn.columns[:16]):]:
    df_3z = df_3z[(df_3z[x] < 3) & (df_3z[x] > -3)]
    
# drop _z columns
df_3z = df_3z.drop(columns=df_3z.columns[-len(df_imputed_knn.columns[:16]):])

print('Number of Outliers:',len(df_imputed_knn)-len(df_3z))
# Out:
# Number of Outliers: 514

# %%
# 3 z aralik disindaki datanin outlier kabul edildiginde olusturulan yeni dataframe
# boolen degere sahip feature lar degerlendirmeye alinmamistir.
df_3z.iloc[:,:16]
# Out:
#         MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  WindGustSpeed  \
# 35704      20.4     26.5       0.0         6.80      2.20           39.0
# 116409     24.7     35.5       0.0        11.74     10.80           44.0
# 51098       8.9     26.1       0.0         5.20     12.10           44.0
# 35651      14.3     25.2       0.0         8.80     11.20           43.0
# 43028      20.9     23.9       0.0         6.08      7.90           41.0
# ...         ...      ...       ...          ...       ...            ...
# 99115      10.6     21.0       0.4         3.32      9.48           28.0
# 94180       6.7     23.9       0.0         4.80     10.40           37.0
# 1636        6.4     11.9       4.2         2.52      2.76           44.0
# 86229      17.5     30.7       0.0         7.40     11.60           35.0
# 74042      16.2     24.3       0.0         5.14     10.80           46.0
#
#         WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  Pressure9am  \
# 35704            7.0          17.0         83.0         92.0       1011.9
# 116409          19.0           9.0         29.0         18.0       1018.6
# 51098            2.0          22.0         63.0         27.0       1015.4
# 35651           24.0          24.0         45.0         44.0       1009.6
# 43028           22.0          26.0         75.0         79.0       1021.1
# ...              ...           ...          ...          ...          ...
# 99115            6.0          11.0         82.0         37.0       1023.7
# 94180            0.0          28.0         55.0         32.0       1017.9
# 1636            15.0          17.0         89.0         85.0       1012.6
# 86229            7.0          20.0         50.0         35.0       1014.8
# 74042           22.0          30.0         72.0         50.0       1008.1
#
#         Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm
# 35704        1010.5       7.0       8.0     22.1     21.6
# 116409       1014.1       2.4       1.0     27.9     34.3
# 51098        1010.1       1.2       2.0     14.3     25.4
# 35651        1005.6       1.0       3.0     18.9     23.3
# 43028        1018.9       7.0       5.2     22.3     23.3
# ...             ...       ...       ...      ...      ...
# 99115        1017.7       1.4       2.6     14.5     20.8
# 94180        1015.3       7.0       4.0     17.0     22.3
# 1636         1010.6       8.0       8.0      8.7     10.7
# 86229        1013.1       1.0       0.0     27.9     28.2
# 74042        1007.4       3.6       2.8     17.2     22.3
#
# [9140 rows x 16 columns]

# %%
# after dropping outliers
df_3z.iloc[:,:16].describe().T.round(2)
# Out:
#                 count     mean    std    min     25%      50%     75%      max
# MinTemp        9140.0    12.15   6.35   -6.3     7.5    11.90    16.8    29.70
# MaxTemp        9140.0    23.26   6.91    2.5    18.0    22.70    28.2    44.20
# Rainfall       9140.0     1.49   3.95    0.0     0.0     0.00     0.6    28.60
# Evaporation    9140.0     4.95   3.04    0.0     2.6     4.40     6.7    16.48
# Sunshine       9140.0     7.62   3.45    0.0     5.1     8.30    10.4    14.30
# WindGustSpeed  9140.0    38.76  12.16    9.0    30.0    37.00    46.0    80.00
# WindSpeed9am   9140.0    13.56   8.15    0.0     7.0    13.00    19.0    39.00
# WindSpeed3pm   9140.0    18.27   8.18    0.0    13.0    17.20    24.0    44.00
# Humidity9am    9140.0    68.92  18.41   12.0    57.0    70.00    83.0   100.00
# Humidity3pm    9140.0    51.29  20.17    2.0    37.0    52.00    65.0   100.00
# Pressure9am    9140.0  1018.10   6.61  997.2  1013.6  1018.02  1022.7  1038.30
# Pressure3pm    9140.0  1015.66   6.57  995.2  1011.0  1015.60  1020.2  1035.70
# Cloud9am       9140.0     4.26   2.65    0.0     1.8     4.40     7.0     8.00
# Cloud3pm       9140.0     4.39   2.42    0.0     2.2     4.60     7.0     8.00
# Temp9am        9140.0    16.98   6.40   -1.2    12.4    16.70    21.6    35.10
# Temp3pm        9140.0    21.77   6.75    1.3    16.7    21.20    26.5    42.50

# %%
# before dropping outliers
df_imputed_knn.iloc[:,:16].describe().T.round(2)
# Out:
#                 count     mean    std    min      25%      50%     75%     max
# MinTemp        9654.0    12.28   6.40   -6.7     7.60    12.00    17.0    33.9
# MaxTemp        9654.0    23.31   7.10   -3.1    18.00    22.70    28.3    47.0
# Rainfall       9654.0     2.35   8.78    0.0     0.00     0.00     0.6   371.0
# Evaporation    9654.0     5.20   3.76    0.0     2.60     4.52     6.8    60.2
# Sunshine       9654.0     7.55   3.50    0.0     4.96     8.20    10.4    14.3
# WindGustSpeed  9654.0    39.83  13.51    9.0    31.00    38.90    47.0   124.0
# WindSpeed9am   9654.0    14.08   8.79    0.0     7.00    13.00    19.0    67.0
# WindSpeed3pm   9654.0    18.68   8.73    0.0    13.00    19.00    24.0    83.0
# Humidity9am    9654.0    68.69  19.01    4.0    57.00    70.00    83.0   100.0
# Humidity3pm    9654.0    51.41  20.71    1.0    36.00    52.00    66.0   100.0
# Pressure9am    9654.0  1017.75   6.87  984.6  1013.20  1017.80  1022.5  1038.9
# Pressure3pm    9654.0  1015.33   6.83  982.2  1010.68  1015.31  1020.0  1036.6
# Cloud9am       9654.0     4.30   2.65    0.0     2.00     4.60     7.0     8.0
# Cloud3pm       9654.0     4.44   2.42    0.0     2.20     4.60     7.0     8.0
# Temp9am        9654.0    17.08   6.51   -4.3    12.40    16.80    21.8    37.3
# Temp3pm        9654.0    21.80   6.95   -3.9    16.70    21.20    26.6    44.8

# %% [markdown]
# ### Isolation Forest
# Return the anomaly score of each sample using the IsolationForest algorithm
#
# The IsolationForest ‘isolates’ observations by randomly selecting a feature and then randomly selecting a split value between the maximum and minimum values of the selected feature.
#
# Since recursive partitioning can be represented by a tree structure, the number of splittings required to isolate a sample is equivalent to the path length from the root node to the terminating node.
#
# This path length, averaged over a forest of such random trees, is a measure of normality and our decision function.
#
# Random partitioning produces noticeably shorter paths for anomalies. Hence, when a forest of random trees collectively produce shorter path lengths for particular samples, they are highly likely to be anomalies.

# %%
df_imputed_knn.columns
# Out:
# Index(['MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation', 'Sunshine',
#        'WindGustSpeed', 'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am',
#        'Humidity3pm', 'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm',
#        'Temp9am', 'Temp3pm', 'RainToday', 'RainTomorrow', 'WindDir9am_ENE',
#        'WindDir9am_ESE', 'WindDir9am_N', 'WindDir9am_NE', 'WindDir9am_NNE',
#        'WindDir9am_NNW', 'WindDir9am_NW', 'WindDir9am_S', 'WindDir9am_SE',
#        'WindDir9am_SSE', 'WindDir9am_SSW', 'WindDir9am_SW', 'WindDir9am_W',
#        'WindDir9am_WNW', 'WindDir9am_WSW', 'WindDir3pm_ENE', 'WindDir3pm_ESE',
#        'WindDir3pm_N', 'WindDir3pm_NE', 'WindDir3pm_NNE', 'WindDir3pm_NNW',
#        'WindDir3pm_NW', 'WindDir3pm_S', 'WindDir3pm_SE', 'WindDir3pm_SSE',
#        'WindDir3pm_SSW', 'WindDir3pm_SW', 'WindDir3pm_W', 'WindDir3pm_WNW',
#        'WindDir3pm_WSW', 'WindGustDir_ENE', 'WindGustDir_ESE', 'WindGustDir_N',
#        'WindGustDir_NE', 'WindGustDir_NNE', 'WindGustDir_NNW',
#        'WindGustDir_NW', 'WindGustDir_S', 'WindGustDir_SE', 'WindGustDir_SSE',
#        'WindGustDir_SSW', 'WindGustDir_SW', 'WindGustDir_W', 'WindGustDir_WNW',
#        'WindGustDir_WSW'],
#       dtype='object')

# %% [markdown]
# while 'RainTomorrow' is the target label, others are the independent features

# %%
from sklearn.ensemble import IsolationForest
from sklearn.model_selection import train_test_split

df_isolation_forest = df_imputed_knn.copy()

y_iso = df_isolation_forest['RainTomorrow']
X_iso = df_isolation_forest.drop(['RainTomorrow'], axis=1)

clf = IsolationForest(n_estimators=100, max_samples='auto', contamination=0.10, random_state=42)
clf.fit(X_iso)
y_pred = clf.predict(X_iso)

# the model will predict an inlier with a label of +1 and an outlier with a label of -1

outliers_values = X_iso[clf.predict(X_iso) == -1]
outliers_values
# Out:
#         MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  WindGustSpeed  \
# 75865       7.3     12.2      15.0         2.00      4.10           93.0
# 43295      14.9     24.5       0.0         5.18      3.18           61.0
# 32797       5.8     16.1       0.0         0.20      6.80           31.0
# 53357      -3.1      2.9       0.0         1.60      1.42           48.0
# 70569       9.5     11.8       3.8         1.40      3.10           26.0
# ...         ...      ...       ...          ...       ...            ...
# 51391       6.2     10.0      24.6         1.92      1.74           54.0
# 44312      19.5     20.5       0.0         6.20      7.48           78.0
# 108040     25.0     42.7       0.0        18.40     13.00           52.0
# 57059       4.3      7.8       4.0         1.90      2.12           61.0
# 38478       4.5      9.4       0.0         3.80      3.30           54.0
#
#         WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  ...  \
# 75865           56.0          43.0         71.0         84.0  ...
# 43295           15.0           6.0         75.0         74.0  ...
# 32797           13.0          11.0         82.0         31.0  ...
# 53357           28.0          15.0        100.0         81.0  ...
# 70569            9.0          13.0         99.0         95.0  ...
# ...              ...           ...          ...          ...  ...
# 51391           24.0          24.0         74.0         82.0  ...
# 44312           52.0          30.0         67.0         60.0  ...
# 108040          15.0          22.0         28.0         10.0  ...
# 57059           31.0          20.0         99.0         95.0  ...
# 38478           17.0          28.0         85.0         78.0  ...
#
#         WindGustDir_NNW  WindGustDir_NW  WindGustDir_S  WindGustDir_SE  \
# 75865               0.0             0.0            0.0             0.0
# 43295               1.0             0.0            0.0             0.0
# 32797               0.0             0.0            0.0             0.0
# 53357               0.0             0.0            0.0             0.0
# 70569               0.0             0.0            0.0             0.0
# ...                 ...             ...            ...             ...
# 51391               0.0             0.0            1.0             0.0
# 44312               0.0             0.0            0.0             0.0
# 108040              0.0             0.0            0.0             0.0
# 57059               0.0             0.0            0.0             0.0
# 38478               0.0             0.0            0.0             0.0
#
#         WindGustDir_SSE  WindGustDir_SSW  WindGustDir_SW  WindGustDir_W  \
# 75865               0.0              0.0             0.0            1.0
# 43295               0.0              0.0             0.0            0.0
# 32797               0.0              0.0             0.0            1.0
# 53357               0.0              0.0             0.0            0.0
# 70569               0.0              0.0             0.0            0.0
# ...                 ...              ...             ...            ...
# 51391               0.0              0.0             0.0            0.0
# 44312               0.0              1.0             0.0            0.0
# 108040              0.0              0.0             1.0            0.0
# 57059               0.0              0.0             0.0            0.0
# 38478               0.0              0.0             0.0            1.0
#
#         WindGustDir_WNW  WindGustDir_WSW
# 75865               0.0              0.0
# 43295               0.0              0.0
# 32797               0.0              0.0
# 53357               0.0              1.0
# 70569               0.0              0.0
# ...                 ...              ...
# 51391               0.0              0.0
# 44312               0.0              0.0
# 108040              0.0              0.0
# 57059               0.0              0.0
# 38478               0.0              0.0
#
# [966 rows x 62 columns]

# %%
f"{len(outliers_values)} rows are outliers"
# Out:
# '966 rows are outliers'

# %% [markdown]
# ### LocalOutlierFactor
# Unsupervised Outlier Detection using Local Outlier Factor (LOF)
#
# The anomaly score of each sample is called Local Outlier Factor. It measures the local deviation of density of a given sample with respect to its neighbors. It is local in that the anomaly score depends on how isolated the object is with respect to the surrounding neighborhood. More precisely, locality is given by k-nearest neighbors, whose distance is used to estimate the local density. By comparing the local density of a sample to the local densities of its neighbors, one can identify samples that have a substantially lower density than their neighbors. These are considered outliers.

# %% [markdown]
# * Her örneğin anomali puanına LocalOutlierFactor denir. Belirli bir örneğin yoğunluğunun komşularına göre yerel sapmasını ölçer. Anormallik puanının, nesnenin çevreleyen komşuluğa göre ne kadar izole olduğuna bağlı olduğu için yereldir.
# * Daha kesin olarak, yerellik, uzaklığı yerel yoğunluğu tahmin etmek için kullanılan knn tarafindan verilir. Bir örneğin yerel yoğunluğunu komşularının yerel yoğunluklarıyla karşılaştırarak, komşularından önemli ölçüde daha düşük yoğunluğa sahip örnekler belirlenebilir. Bunlar aykırı değerler olarak kabul edilir.

# %%
from sklearn.neighbors import LocalOutlierFactor
from sklearn.preprocessing import MinMaxScaler

df_lof = df_imputed_knn.copy()

scaler = MinMaxScaler()

columns = df_lof.columns

#note that we transform the data with MinMaxScaler
df_lof_scaled = scaler.fit_transform(df_lof)
df_lof_scaled = pd.DataFrame(df_lof, columns=columns)

y = df_lof_scaled['RainTomorrow']
X = df_lof_scaled.drop(['RainTomorrow'], axis=1)

# fit the model for outlier detection (default)
clf = LocalOutlierFactor(n_neighbors=20, contamination=0.1)

# use fit_predict to compute the predicted labels of the training samples
# (when LOF is used for outlier detection, the estimator has no predict,
# decision_function and score_samples methods).

y_pred = clf.fit_predict(X)
X_scores = clf.negative_outlier_factor_
np.sort(X_scores)[:100]
# Out:
# array([-6.07063572, -2.09659928, -2.02572902, -1.92858082, -1.90855097,
#        -1.89910979, -1.84421057, -1.81665194, -1.80473587, -1.79989154,
#        -1.78931354, -1.77394214, -1.75098994, -1.73014847, -1.72650882,
#        -1.70577302, -1.70463052, -1.69383985, -1.67886189, -1.67699828,
#        -1.67485174, -1.67213043, -1.66012225, -1.64152544, -1.64089129,
#        -1.63837754, -1.63578702, -1.63456896, -1.63351665, -1.62379624,
#        -1.61945795, -1.61816089, -1.61427562, -1.60581065, -1.60337487,
#        -1.60260639, -1.5992142 , -1.59766069, -1.59309349, -1.5906444 ,
#        -1.58012589, -1.57497448, -1.56832486, -1.56418313, -1.56125022,
#        -1.554549  , -1.5454887 , -1.54293526, -1.54084873, -1.53302917,
#        -1.52995808, -1.52303035, -1.52029303, -1.51946412, -1.51876932,
#        -1.5160931 , -1.51124489, -1.50859598, -1.50807419, -1.50735083,
#        -1.50691323, -1.50523409, -1.50492011, -1.50228248, -1.50014538,
#        -1.49912051, -1.49817328, -1.49684672, -1.49681369, -1.49648057,
#        -1.4949261 , -1.49363885, -1.49336588, -1.4925381 , -1.49221446,
#        -1.49184077, -1.49151873, -1.49096239, -1.48939379, -1.48899391,
#        -1.47264284, -1.46707303, -1.46699981, -1.46695367, -1.46582553,
#        -1.46247008, -1.45957983, -1.45450591, -1.45360309, -1.44840017,
#        -1.44715873, -1.446099  , -1.44403405, -1.44290583, -1.43973272,
#        -1.4385206 , -1.43497775, -1.43212508, -1.43199267, -1.43191991])

# %%
# threshold = X_scores.mean()-3*X_scores.std()
threshold = np.sort(X_scores)[len(X_scores)//10]
threshold
# Out:
# -1.1678584033879502

# %%
X[(X_scores > threshold)==False].shape
# Out:
# (966, 62)

# %%
plt.figure(figsize=(12,6))
sns.histplot(x=X_scores)
plt.xlim((-1.5,-0.9))
plt.axvline(x=threshold,color='red')
plt.xlabel("Outliers by Threshold in Histogram")
plt.show()

# %% [markdown]
# ### Handling Ouliers

# %%
# Dropping observations with outliers
df_numeric_no = df_numeric[~((df_numeric < (Q1 - 1.5 * IQR)) |(df_numeric > (Q3 + 1.5 * IQR))).any(axis=1)]
print(df_numeric.shape)
print(df_numeric_no.shape)
# Out:
# (9654, 16)
# (7047, 16)

# %%
df_numeric_no
# Out:
#         MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  WindGustSpeed  \
# 35704      20.4     26.5       0.0         6.80      2.20           39.0
# 116409     24.7     35.5       0.0        11.74     10.80           44.0
# 51098       8.9     26.1       0.0         5.20     12.10           44.0
# 35651      14.3     25.2       0.0         8.80     11.20           43.0
# 43028      20.9     23.9       0.0         6.08      7.90           41.0
# ...         ...      ...       ...          ...       ...            ...
# 114118     17.7     28.4       0.0         6.08      9.78           43.0
# 99115      10.6     21.0       0.4         3.32      9.48           28.0
# 94180       6.7     23.9       0.0         4.80     10.40           37.0
# 86229      17.5     30.7       0.0         7.40     11.60           35.0
# 74042      16.2     24.3       0.0         5.14     10.80           46.0
#
#         WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  Pressure9am  \
# 35704            7.0          17.0         83.0         92.0       1011.9
# 116409          19.0           9.0         29.0         18.0       1018.6
# 51098            2.0          22.0         63.0         27.0       1015.4
# 35651           24.0          24.0         45.0         44.0       1009.6
# 43028           22.0          26.0         75.0         79.0       1021.1
# ...              ...           ...          ...          ...          ...
# 114118          20.0          22.0         67.0         52.0       1016.4
# 99115            6.0          11.0         82.0         37.0       1023.7
# 94180            0.0          28.0         55.0         32.0       1017.9
# 86229            7.0          20.0         50.0         35.0       1014.8
# 74042           22.0          30.0         72.0         50.0       1008.1
#
#         Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm
# 35704        1010.5       7.0       8.0     22.1     21.6
# 116409       1014.1       2.4       1.0     27.9     34.3
# 51098        1010.1       1.2       2.0     14.3     25.4
# 35651        1005.6       1.0       3.0     18.9     23.3
# 43028        1018.9       7.0       5.2     22.3     23.3
# ...             ...       ...       ...      ...      ...
# 114118       1013.9       4.6       3.6     22.1     27.6
# 99115        1017.7       1.4       2.6     14.5     20.8
# 94180        1015.3       7.0       4.0     17.0     22.3
# 86229        1013.1       1.0       0.0     27.9     28.2
# 74042        1007.4       3.6       2.8     17.2     22.3
#
# [7047 rows x 16 columns]

# %% [markdown]
# ### Replacing outliers of a variable with its median

# %%
features = df_imputed_knn.columns[:16]
features
# Out:
# Index(['MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation', 'Sunshine',
#        'WindGustSpeed', 'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am',
#        'Humidity3pm', 'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm',
#        'Temp9am', 'Temp3pm'],
#       dtype='object')

# %%
# visualize outliers before Replacing outliers of a variable with its median

df_numeric = df_imputed_knn.iloc[:,:16].select_dtypes(include=numerics)
plt.figure(figsize=(20,20))
for k,v in enumerate(features):
    plt.subplot(4,4,k+1)
    sns.boxplot(data=df_numeric, x=v)

# %%
for i in features:
    Q1_feature = df_numeric[i].quantile(0.25)
    Q3_feature = df_numeric[i].quantile(0.75)
    IQR_feature = Q3_feature - Q1_feature

    df_numeric[i][((df_numeric[i] < (
        Q1_feature - 1.5 * IQR_feature)) |(df_numeric[i] > (Q3_feature + 1.5 * IQR_feature)))] = df_numeric[i].median()

# %%
df_numeric
# Out:
#         MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  WindGustSpeed  \
# 35704      20.4     26.5       0.0         6.80      2.20           39.0
# 116409     24.7     35.5       0.0        11.74     10.80           44.0
# 75865       7.3     12.2       0.0         2.00      4.10           38.9
# 51098       8.9     26.1       0.0         5.20     12.10           44.0
# 35651      14.3     25.2       0.0         8.80     11.20           43.0
# ...         ...      ...       ...          ...       ...            ...
# 99115      10.6     21.0       0.4         3.32      9.48           28.0
# 94180       6.7     23.9       0.0         4.80     10.40           37.0
# 1636        6.4     11.9       0.0         2.52      2.76           44.0
# 86229      17.5     30.7       0.0         7.40     11.60           35.0
# 74042      16.2     24.3       0.0         5.14     10.80           46.0
#
#         WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  Pressure9am  \
# 35704            7.0          17.0         83.0         92.0       1011.9
# 116409          19.0           9.0         29.0         18.0       1018.6
# 75865           13.0          19.0         71.0         84.0       1005.3
# 51098            2.0          22.0         63.0         27.0       1015.4
# 35651           24.0          24.0         45.0         44.0       1009.6
# ...              ...           ...          ...          ...          ...
# 99115            6.0          11.0         82.0         37.0       1023.7
# 94180            0.0          28.0         55.0         32.0       1017.9
# 1636            15.0          17.0         89.0         85.0       1012.6
# 86229            7.0          20.0         50.0         35.0       1014.8
# 74042           22.0          30.0         72.0         50.0       1008.1
#
#         Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm
# 35704        1010.5       7.0       8.0     22.1     21.6
# 116409       1014.1       2.4       1.0     27.9     34.3
# 75865        1007.3       7.0       7.0     10.2      9.6
# 51098        1010.1       1.2       2.0     14.3     25.4
# 35651        1005.6       1.0       3.0     18.9     23.3
# ...             ...       ...       ...      ...      ...
# 99115        1017.7       1.4       2.6     14.5     20.8
# 94180        1015.3       7.0       4.0     17.0     22.3
# 1636         1010.6       8.0       8.0      8.7     10.7
# 86229        1013.1       1.0       0.0     27.9     28.2
# 74042        1007.4       3.6       2.8     17.2     22.3
#
# [9654 rows x 16 columns]

# %%
# visualize outliers after Replacing outliers of a variable with its median
plt.figure(figsize=(20,20))
for k,v in enumerate(features):
    plt.subplot(4,4,k+1)
    sns.boxplot(data=df_numeric, x=v)

# %% [markdown]
# ### Replacing outliers of a variable according to threshold

# %%
# the threshold observation
df_imputed_knn[(X_scores == threshold)]
# Out:
#        MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  WindGustSpeed  \
# 49379     16.8     28.7       0.0         6.64      8.92           59.0
#
#        WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  ...  \
# 49379           2.0          30.0         54.0         44.0  ...
#
#        WindGustDir_NNW  WindGustDir_NW  WindGustDir_S  WindGustDir_SE  \
# 49379              0.0             0.0            0.0             0.0
#
#        WindGustDir_SSE  WindGustDir_SSW  WindGustDir_SW  WindGustDir_W  \
# 49379              0.0              0.0             0.0            0.0
#
#        WindGustDir_WNW  WindGustDir_WSW
# 49379              1.0              0.0
#
# [1 rows x 63 columns]

# %%
threshold_row = df_imputed_knn[(X_scores == threshold)]
outliers = df_imputed_knn[(X_scores < threshold)]
# We get rid of the indexes of outliers and transformed them into array
outliers.to_records(index = False)
# We define a variable for outlier array
outliers_array = outliers.to_records(index = False)

# We replace all the outliers with the threshold row
outliers_array[:] = threshold_row.to_records(index = False)

df_numeric_no3 = df_imputed_knn.copy()

# the outlier observations after replacement by the threshold observation
df_numeric_no3[(X_scores < threshold)] = pd.DataFrame(outliers_array, index = df_numeric_no3[(X_scores < threshold)].index)
df_numeric_no3[(X_scores < threshold)].head()
# Out:
#         MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  WindGustSpeed  \
# 75865      16.8     28.7       0.0         6.64      8.92           59.0
# 137138     16.8     28.7       0.0         6.64      8.92           59.0
# 103441     16.8     28.7       0.0         6.64      8.92           59.0
# 52234      16.8     28.7       0.0         6.64      8.92           59.0
# 108929     16.8     28.7       0.0         6.64      8.92           59.0
#
#         WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  ...  \
# 75865            2.0          30.0         54.0         44.0  ...
# 137138           2.0          30.0         54.0         44.0  ...
# 103441           2.0          30.0         54.0         44.0  ...
# 52234            2.0          30.0         54.0         44.0  ...
# 108929           2.0          30.0         54.0         44.0  ...
#
#         WindGustDir_NNW  WindGustDir_NW  WindGustDir_S  WindGustDir_SE  \
# 75865               0.0             0.0            0.0             0.0
# 137138              0.0             0.0            0.0             0.0
# 103441              0.0             0.0            0.0             0.0
# 52234               0.0             0.0            0.0             0.0
# 108929              0.0             0.0            0.0             0.0
#
#         WindGustDir_SSE  WindGustDir_SSW  WindGustDir_SW  WindGustDir_W  \
# 75865               0.0              0.0             0.0            0.0
# 137138              0.0              0.0             0.0            0.0
# 103441              0.0              0.0             0.0            0.0
# 52234               0.0              0.0             0.0            0.0
# 108929              0.0              0.0             0.0            0.0
#
#         WindGustDir_WNW  WindGustDir_WSW
# 75865               1.0              0.0
# 137138              1.0              0.0
# 103441              1.0              0.0
# 52234               1.0              0.0
# 108929              1.0              0.0
#
# [5 rows x 63 columns]
